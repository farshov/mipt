# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
def plotting(x, N, coef, name):
    ## DTFT part 
    plt.figure(figsize=[6, 4], dpi=100)
    M=2048
    plt.plot(np.arange(M)/M, abs(np.fft.fft(x, M)), 'g'); 

    # Zero Padding
    # also we can use np.fft.fft(x, N+Nz)
    Nz=N*coef
    x=np.hstack((x, np.zeros(Nz)))

    ## DFT part 
    N=x.size
    plt.stem(np.arange(N)/N, abs(np.fft.fft(x, N)), 'b', 'b.'); 
    #plt.stem(np.arange(N)/N, abs(np.fft.fft(x, N)), 'b', 'b.'); 



    plt.xticks(np.arange(0, 1.1, 0.1))
    plt.axis(xmin=-0.02, xmax=0.5, ymin=-1)
    #plt.axis(xmin=-0.02, xmax=1, ymin=-0.4)
    plt.xlabel(u'$\\nu$')
    plt.ylabel(u'$|X(\\nu)|$')
    plt.grid()
    plt.title(u'DTFT and DFT of $x(k)$')
    #plt.savefig('graph1.png', format = 'png')
    plt.savefig(name, format = 'png')
    #plt.show()



    ## Signal part
    plt.figure(figsize=[6, 4], dpi=100)
    plt.stem(np.arange(x.size), x, 'b', 'b.'); 
    plt.xticks(np.arange(0, x.size, max(1, x.size//5)))
    plt.title(u'Signal $x(k)$, N=%i' %(x.size));
    plt.xlabel(u'$k$');
    plt.ylabel(u'$x(k)$');
    plt.grid()
    plt.show()

# %%
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k/5);
#x=np.sin(2*np.pi*k/5);
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);

# Window 
window = signal.boxcar(x.size)
#window = signal.bartlett(x.size)
#window = signal.hann(x.size)
#window = signal.hamming(x.size)
#window = signal.blackman(x.size)
x=x*window

# %% [markdown]
# # Part 1

# %%
N=20
coef=0
name = 'images_2/part_1/plot_n20'
x=np.ones(N)

plotting(x, N, coef, name)

# %%
N=20
coef=1
name = 'images_2/part_1/plot_1n_zeros'
x=np.ones(N)

plotting(x, N, coef, name)

# %%
N=20
coef=2
name = 'images_2/part_1/plot_2n_zeros'
x=np.ones(N)

plotting(x, N, coef, name)

# %%
N=20
coef=3
name = 'images_2/part_1/plot_3n_zeros'
x=np.ones(N)

plotting(x, N, coef, name)

# %% [markdown]
# # Part 2

# %%
N=20
coef=0
name = 'images_2/part_2/plot_n20'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k/5);

plotting(x, N, coef, name)

# %%
N=40
coef=0
name = 'images_2/part_2/plot_n40'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k/5);

plotting(x, N, coef, name)

# %%
N=20
coef=3
name = 'images_2/part_2/plot_n20_3n_zeros'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k/5);

plotting(x, N, coef, name)

# %%
N=40
coef=3
name = 'images_2/part_2/plot_n40_3n_zeros'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k/5);

plotting(x, N, coef, name)

# %% [markdown]
# # Part 3

# %%
N=64
coef=0
name = 'images_2/part_3/f1_n64'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);
window = signal.boxcar(x.size)
x=x*window

plotting(x, N, coef, name)

# %%
N=64
coef=0
name = 'images_2/part_3/f2_n64'
x=np.ones(N)
k=np.arange(N)
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);
window = signal.boxcar(x.size)
x=x*window

plotting(x, N, coef, name)

# %%
N=128
coef=0
name = 'images_2/part_3/f1_n128'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);
window = signal.boxcar(x.size)
x=x*window

plotting(x, N, coef, name)

# %%
N=128
coef=0
name = 'images_2/part_3/f2_n128'
x=np.ones(N)
k=np.arange(N)
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);
window = signal.boxcar(x.size)
x=x*window

plotting(x, N, coef, name)

# %%
N=64
coef=1
name = 'images_2/part_3/f1_n64_n_zeros'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);
window = signal.boxcar(x.size)
x=x*window

plotting(x, N, coef, name)

# %%
N=64
coef=1
name = 'images_2/part_3/f2_n64_n_zeros'
x=np.ones(N)
k=np.arange(N)
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);
window = signal.boxcar(x.size)
x=x*window

plotting(x, N, coef, name)

# %%
N=128
coef=1
name = 'images_2/part_3/f1_n128_n_zeros'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);
window = signal.boxcar(x.size)
x=x*window

plotting(x, N, coef, name)

# %%
N=128
coef=1
name = 'images_2/part_3/f2_n128_n_zeros'
x=np.ones(N)
k=np.arange(N)
#x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*8.5/64);
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);
window = signal.boxcar(x.size)
x=x*window

plotting(x, N, coef, name)

# %% [markdown]
# # Part 4

# %%
def plotting_2(x, N, coef, name):
    ## DTFT part 
    plt.figure(figsize=[6, 4], dpi=100)
    M=2048
    plt.plot(np.arange(M)/M, abs(np.fft.fft(x, M)), 'g'); 

    # Zero Padding
    # also we can use np.fft.fft(x, N+Nz)
    Nz=N*coef
    x=np.hstack((x, np.zeros(Nz)))

    ## DFT part 
    N=x.size
    plt.stem(np.arange(N)/N, abs(np.fft.fft(x, N)), 'b', 'b.'); 
    #plt.stem(np.arange(N)/N, abs(np.fft.fft(x, N)), 'b', 'b.'); 



    plt.xticks(np.arange(0, 1.1, 0.1))
    plt.axis(xmin=-0.02, xmax=0.5, ymin=-1)
    #plt.axis(xmin=-0.02, xmax=1, ymin=-0.4)
    plt.xlabel(u'$\\nu$')
    plt.ylabel(u'$|X(\\nu)|$')
    plt.grid()
    plt.title(u'DTFT and DFT of $x(k)$')
    #plt.savefig('graph1.png', format = 'png')
    plt.savefig(name, format = 'png')
    #plt.show()



    ## Signal part
    plt.figure(figsize=[6, 4], dpi=100)
    plt.stem(np.arange(x.size), x, 'b', 'b.'); 
    plt.xticks(np.arange(0, x.size, max(1, x.size//5)))
    plt.title(u'Signal $x(k)$, N=%i' %(x.size));
    plt.xlabel(u'$k$');
    plt.ylabel(u'$x(k)$');
    plt.grid()
    plt.show()

# %%
N=64
coef=1
name = 'images_2/part_4/plot_w1'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);

# Window 
window = signal.boxcar(x.size)
#window = signal.bartlett(x.size)
#window = signal.hann(x.size)
#window = signal.hamming(x.size)
#window = signal.blackman(x.size)
x=x*window
plotting_2(x, N, coef, name)

# %%
N=64
coef=1
name = 'images_2/part_4/plot_w2'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);

# Window 
#window = signal.boxcar(x.size)
window = signal.bartlett(x.size)
#window = signal.hann(x.size)
#window = signal.hamming(x.size)
#window = signal.blackman(x.size)
x=x*window
plotting_2(x, N, coef, name)

# %%
N=64
coef=1
name = 'images_2/part_4/plot_w3'
x=np.ones(N)
k=np.arange(N)
x=np.cos(2*np.pi*k*8/64)+np.cos(2*np.pi*k*10.5/64);

# Window 
#window = signal.boxcar(x.size)
#window = signal.bartlett(x.size)
window = signal.hann(x.size)
#window = signal.hamming(x.size)
#window = signal.blackman(x.size)
x=x*window
plotting_2(x, N, coef, name)
